# %% [markdown]
# <center>
# <h1 style="color:red; font-size:70px;"> Studio delle performance</h1>

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

from tensorflow import keras
from sklearn.metrics import confusion_matrix, top_k_accuracy_score
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 2025-09-11 17:31:24.462668: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-09-11 17:31:26.042094: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-09-11 17:31:27.014733: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757604687.995429  330481 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757604688.192428  330481 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1757604689.474766  330481 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757604689.475027  330481 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757604689.475064  330481 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757604689.475078  330481 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-09-11 17:31:29.586630: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Confronto iniziale - dropout

# %%
# Importo il validation dataset per provare a confrontare le performance delle due reti
valDir = "../Dataset/test"  
datagen = ImageDataGenerator(rescale=1./255)

valDat = datagen.flow_from_directory(
    valDir,
    target_size=(48, 48),
    color_mode="grayscale",
    class_mode="categorical",
    shuffle=True
)


img = []
lab = []
conta = 0
for i, l in valDat:
    img.append(i)
    lab.append(l)
    
    conta += 1
    print("Caricato " + str(conta) + " batch")

    if conta >= 200:
        break

# Unisci tutti i batch
img = np.concatenate(img, axis=0)
lab = np.concatenate(lab, axis=0)
# Out:
# Found 7178 images belonging to 7 classes.
# Caricato 1 batch
# Caricato 2 batch
# Caricato 3 batch
# Caricato 4 batch
# Caricato 5 batch
# Caricato 6 batch
# Caricato 7 batch
# Caricato 8 batch
# Caricato 9 batch
# Caricato 10 batch
# Caricato 11 batch
# Caricato 12 batch
# Caricato 13 batch
# Caricato 14 batch
# Caricato 15 batch
# Caricato 16 batch
# Caricato 17 batch
# Caricato 18 batch
# Caricato 19 batch
# Caricato 20 batch
# Caricato 21 batch
# Caricato 22 batch
# Caricato 23 batch
# Caricato 24 batch
# Caricato 25 batch
# Caricato 26 batch
# Caricato 27 batch
# Caricato 28 batch
# Caricato 29 batch
# Caricato 30 batch
# Caricato 31 batch
# Caricato 32 batch
# Caricato 33 batch
# Caricato 34 batch
# Caricato 35 batch
# Caricato 36 batch
# Caricato 37 batch
# Caricato 38 batch
# Caricato 39 batch
# Caricato 40 batch
# Caricato 41 batch
# Caricato 42 batch
# Caricato 43 batch
# Caricato 44 batch
# Caricato 45 batch
# Caricato 46 batch
# Caricato 47 batch
# Caricato 48 batch
# Caricato 49 batch
# Caricato 50 batch
# Caricato 51 batch
# Caricato 52 batch
# Caricato 53 batch
# Caricato 54 batch
# Caricato 55 batch
# Caricato 56 batch
# Caricato 57 batch
# Caricato 58 batch
# Caricato 59 batch
# Caricato 60 batch
# Caricato 61 batch
# Caricato 62 batch
# Caricato 63 batch
# Caricato 64 batch
# Caricato 65 batch
# Caricato 66 batch
# Caricato 67 batch
# Caricato 68 batch
# Caricato 69 batch
# Caricato 70 batch
# Caricato 71 batch
# Caricato 72 batch
# Caricato 73 batch
# Caricato 74 batch
# Caricato 75 batch
# Caricato 76 batch
# Caricato 77 batch
# Caricato 78 batch
# Caricato 79 batch
# Caricato 80 batch
# Caricato 81 batch
# Caricato 82 batch
# Caricato 83 batch
# Caricato 84 batch
# Caricato 85 batch
# Caricato 86 batch
# Caricato 87 batch
# Caricato 88 batch
# Caricato 89 batch
# Caricato 90 batch
# Caricato 91 batch
# Caricato 92 batch
# Caricato 93 batch
# Caricato 94 batch
# Caricato 95 batch
# Caricato 96 batch
# Caricato 97 batch
# Caricato 98 batch
# Caricato 99 batch
# Caricato 100 batch
# Caricato 101 batch
# Caricato 102 batch
# Caricato 103 batch
# Caricato 104 batch
# Caricato 105 batch
# Caricato 106 batch
# Caricato 107 batch
# Caricato 108 batch
# Caricato 109 batch
# Caricato 110 batch
# Caricato 111 batch
# Caricato 112 batch
# Caricato 113 batch
# Caricato 114 batch
# Caricato 115 batch
# Caricato 116 batch
# Caricato 117 batch
# Caricato 118 batch
# Caricato 119 batch
# Caricato 120 batch
# Caricato 121 batch
# Caricato 122 batch
# Caricato 123 batch
# Caricato 124 batch
# Caricato 125 batch
# Caricato 126 batch
# Caricato 127 batch
# Caricato 128 batch
# Caricato 129 batch
# Caricato 130 batch
# Caricato 131 batch
# Caricato 132 batch
# Caricato 133 batch
# Caricato 134 batch
# Caricato 135 batch
# Caricato 136 batch
# Caricato 137 batch
# Caricato 138 batch
# Caricato 139 batch
# Caricato 140 batch
# Caricato 141 batch
# Caricato 142 batch
# Caricato 143 batch
# Caricato 144 batch
# Caricato 145 batch
# Caricato 146 batch
# Caricato 147 batch
# Caricato 148 batch
# Caricato 149 batch
# Caricato 150 batch
# Caricato 151 batch
# Caricato 152 batch
# Caricato 153 batch
# Caricato 154 batch
# Caricato 155 batch
# Caricato 156 batch
# Caricato 157 batch
# Caricato 158 batch
# Caricato 159 batch
# Caricato 160 batch
# Caricato 161 batch
# Caricato 162 batch
# Caricato 163 batch
# Caricato 164 batch
# Caricato 165 batch
# Caricato 166 batch
# Caricato 167 batch
# Caricato 168 batch
# Caricato 169 batch
# Caricato 170 batch
# Caricato 171 batch
# Caricato 172 batch
# Caricato 173 batch
# Caricato 174 batch
# Caricato 175 batch
# Caricato 176 batch
# Caricato 177 batch
# Caricato 178 batch
# Caricato 179 batch
# Caricato 180 batch
# Caricato 181 batch
# Caricato 182 batch
# Caricato 183 batch
# Caricato 184 batch
# Caricato 185 batch
# Caricato 186 batch
# Caricato 187 batch
# Caricato 188 batch
# Caricato 189 batch
# Caricato 190 batch
# Caricato 191 batch
# Caricato 192 batch
# Caricato 193 batch
# Caricato 194 batch
# Caricato 195 batch
# Caricato 196 batch
# Caricato 197 batch
# Caricato 198 batch
# Caricato 199 batch
# Caricato 200 batch

# %%
# Funzione per capire la posizione della label corretta fra le guess
def ordGuess(img, lab, names):
    appo = np.zeros((2, 7))
    for n, name in enumerate(names):

        # Importo il modello adeguato
        model = load_model(name)  
        print("Inizio studio per: " + name)
        
        conta = 0
        for i, l in zip(img, lab):
            # Effettuo una predizione per ogni immagine possibile
            pred = model.predict(np.expand_dims(i, axis= 0), verbose=0)

            # Capisco dove era messa la guess vera
            rank = np.argsort(-pred[0])  
            ranks = np.empty_like(rank)
            ranks[rank] = np.arange(0, len(pred[0]))

            # Aggiorno la casella corretta
            appo[n , ranks[np.argmax(l)]] += 1
            conta += 1

            if conta % 40 == 0:
                print("     Effettuate " + str(conta) + " guess")

    return appo

names = ["../Modelli/firstTry.keras", "../Modelli/dropoutTry.keras"]
histo = ordGuess(img, lab, names)
# Out:
# Inizio studio per: Modelli/firstTry.keras
#      Effettuate 40 guess
#      Effettuate 80 guess
#      Effettuate 120 guess
#      Effettuate 160 guess
#      Effettuate 200 guess
#      Effettuate 240 guess
#      Effettuate 280 guess
#      Effettuate 320 guess
#      Effettuate 360 guess
#      Effettuate 400 guess
#      Effettuate 440 guess
#      Effettuate 480 guess
#      Effettuate 520 guess
#      Effettuate 560 guess
#      Effettuate 600 guess
#      Effettuate 640 guess
#      Effettuate 680 guess
#      Effettuate 720 guess
#      Effettuate 760 guess
#      Effettuate 800 guess
#      Effettuate 840 guess
#      Effettuate 880 guess
#      Effettuate 920 guess
#      Effettuate 960 guess
#      Effettuate 1000 guess
#      Effettuate 1040 guess
#      Effettuate 1080 guess
#      Effettuate 1120 guess
#      Effettuate 1160 guess
#      Effettuate 1200 guess
#      Effettuate 1240 guess
#      Effettuate 1280 guess
#      Effettuate 1320 guess
#      Effettuate 1360 guess
#      Effettuate 1400 guess
#      Effettuate 1440 guess
#      Effettuate 1480 guess
#      Effettuate 1520 guess
#      Effettuate 1560 guess
#      Effettuate 1600 guess
#      Effettuate 1640 guess
#      Effettuate 1680 guess
#      Effettuate 1720 guess
#      Effettuate 1760 guess
#      Effettuate 1800 guess
#      Effettuate 1840 guess
#      Effettuate 1880 guess
#      Effettuate 1920 guess
#      Effettuate 1960 guess
#      Effettuate 2000 guess
#      Effettuate 2040 guess
#      Effettuate 2080 guess
#      Effettuate 2120 guess
#      Effettuate 2160 guess
#      Effettuate 2200 guess
#      Effettuate 2240 guess
#      Effettuate 2280 guess
#      Effettuate 2320 guess
#      Effettuate 2360 guess
#      Effettuate 2400 guess
#      Effettuate 2440 guess
#      Effettuate 2480 guess
#      Effettuate 2520 guess
#      Effettuate 2560 guess
#      Effettuate 2600 guess
#      Effettuate 2640 guess
#      Effettuate 2680 guess
#      Effettuate 2720 guess
#      Effettuate 2760 guess
#      Effettuate 2800 guess
#      Effettuate 2840 guess
#      Effettuate 2880 guess
#      Effettuate 2920 guess
#      Effettuate 2960 guess
#      Effettuate 3000 guess
#      Effettuate 3040 guess
#      Effettuate 3080 guess
#      Effettuate 3120 guess
#      Effettuate 3160 guess
#      Effettuate 3200 guess
#      Effettuate 3240 guess
#      Effettuate 3280 guess
#      Effettuate 3320 guess
#      Effettuate 3360 guess
#      Effettuate 3400 guess
#      Effettuate 3440 guess
#      Effettuate 3480 guess
#      Effettuate 3520 guess
#      Effettuate 3560 guess
#      Effettuate 3600 guess
#      Effettuate 3640 guess
#      Effettuate 3680 guess
#      Effettuate 3720 guess
#      Effettuate 3760 guess
#      Effettuate 3800 guess
#      Effettuate 3840 guess
#      Effettuate 3880 guess
#      Effettuate 3920 guess
#      Effettuate 3960 guess
#      Effettuate 4000 guess
#      Effettuate 4040 guess
#      Effettuate 4080 guess
#      Effettuate 4120 guess
#      Effettuate 4160 guess
#      Effettuate 4200 guess
#      Effettuate 4240 guess
#      Effettuate 4280 guess
#      Effettuate 4320 guess
#      Effettuate 4360 guess
#      Effettuate 4400 guess
#      Effettuate 4440 guess
#      Effettuate 4480 guess
#      Effettuate 4520 guess
#      Effettuate 4560 guess
#      Effettuate 4600 guess
#      Effettuate 4640 guess
#      Effettuate 4680 guess
#      Effettuate 4720 guess
#      Effettuate 4760 guess
#      Effettuate 4800 guess
#      Effettuate 4840 guess
#      Effettuate 4880 guess
#      Effettuate 4920 guess
#      Effettuate 4960 guess
#      Effettuate 5000 guess
#      Effettuate 5040 guess
#      Effettuate 5080 guess
#      Effettuate 5120 guess
#      Effettuate 5160 guess
#      Effettuate 5200 guess
#      Effettuate 5240 guess
#      Effettuate 5280 guess
#      Effettuate 5320 guess
#      Effettuate 5360 guess
#      Effettuate 5400 guess
#      Effettuate 5440 guess
#      Effettuate 5480 guess
#      Effettuate 5520 guess
#      Effettuate 5560 guess
#      Effettuate 5600 guess
#      Effettuate 5640 guess
#      Effettuate 5680 guess
#      Effettuate 5720 guess
#      Effettuate 5760 guess
#      Effettuate 5800 guess
#      Effettuate 5840 guess
#      Effettuate 5880 guess
#      Effettuate 5920 guess
#      Effettuate 5960 guess
#      Effettuate 6000 guess
#      Effettuate 6040 guess
#      Effettuate 6080 guess
#      Effettuate 6120 guess
#      Effettuate 6160 guess
#      Effettuate 6200 guess
#      Effettuate 6240 guess
#      Effettuate 6280 guess
#      Effettuate 6320 guess
#      Effettuate 6360 guess
#      Effettuate 6400 guess
# Inizio studio per: Modelli/dropoutTry.keras
#      Effettuate 40 guess
#      Effettuate 80 guess
#      Effettuate 120 guess
#      Effettuate 160 guess
#      Effettuate 200 guess
#      Effettuate 240 guess
#      Effettuate 280 guess
#      Effettuate 320 guess
#      Effettuate 360 guess
#      Effettuate 400 guess
#      Effettuate 440 guess
#      Effettuate 480 guess
#      Effettuate 520 guess
#      Effettuate 560 guess
#      Effettuate 600 guess
#      Effettuate 640 guess
#      Effettuate 680 guess
#      Effettuate 720 guess
#      Effettuate 760 guess
#      Effettuate 800 guess
#      Effettuate 840 guess
#      Effettuate 880 guess
#      Effettuate 920 guess
#      Effettuate 960 guess
#      Effettuate 1000 guess
#      Effettuate 1040 guess
#      Effettuate 1080 guess
#      Effettuate 1120 guess
#      Effettuate 1160 guess
#      Effettuate 1200 guess
#      Effettuate 1240 guess
#      Effettuate 1280 guess
#      Effettuate 1320 guess
#      Effettuate 1360 guess
#      Effettuate 1400 guess
#      Effettuate 1440 guess
#      Effettuate 1480 guess
#      Effettuate 1520 guess
#      Effettuate 1560 guess
#      Effettuate 1600 guess
#      Effettuate 1640 guess
#      Effettuate 1680 guess
#      Effettuate 1720 guess
#      Effettuate 1760 guess
#      Effettuate 1800 guess
#      Effettuate 1840 guess
#      Effettuate 1880 guess
#      Effettuate 1920 guess
#      Effettuate 1960 guess
#      Effettuate 2000 guess
#      Effettuate 2040 guess
#      Effettuate 2080 guess
#      Effettuate 2120 guess
#      Effettuate 2160 guess
#      Effettuate 2200 guess
#      Effettuate 2240 guess
#      Effettuate 2280 guess
#      Effettuate 2320 guess
#      Effettuate 2360 guess
#      Effettuate 2400 guess
#      Effettuate 2440 guess
#      Effettuate 2480 guess
#      Effettuate 2520 guess
#      Effettuate 2560 guess
#      Effettuate 2600 guess
#      Effettuate 2640 guess
#      Effettuate 2680 guess
#      Effettuate 2720 guess
#      Effettuate 2760 guess
#      Effettuate 2800 guess
#      Effettuate 2840 guess
#      Effettuate 2880 guess
#      Effettuate 2920 guess
#      Effettuate 2960 guess
#      Effettuate 3000 guess
#      Effettuate 3040 guess
#      Effettuate 3080 guess
#      Effettuate 3120 guess
#      Effettuate 3160 guess
#      Effettuate 3200 guess
#      Effettuate 3240 guess
#      Effettuate 3280 guess
#      Effettuate 3320 guess
#      Effettuate 3360 guess
#      Effettuate 3400 guess
#      Effettuate 3440 guess
#      Effettuate 3480 guess
#      Effettuate 3520 guess
#      Effettuate 3560 guess
#      Effettuate 3600 guess
#      Effettuate 3640 guess
#      Effettuate 3680 guess
#      Effettuate 3720 guess
#      Effettuate 3760 guess
#      Effettuate 3800 guess
#      Effettuate 3840 guess
#      Effettuate 3880 guess
#      Effettuate 3920 guess
#      Effettuate 3960 guess
#      Effettuate 4000 guess
#      Effettuate 4040 guess
#      Effettuate 4080 guess
#      Effettuate 4120 guess
#      Effettuate 4160 guess
#      Effettuate 4200 guess
#      Effettuate 4240 guess
#      Effettuate 4280 guess
#      Effettuate 4320 guess
#      Effettuate 4360 guess
#      Effettuate 4400 guess
#      Effettuate 4440 guess
#      Effettuate 4480 guess
#      Effettuate 4520 guess
#      Effettuate 4560 guess
#      Effettuate 4600 guess
#      Effettuate 4640 guess
#      Effettuate 4680 guess
#      Effettuate 4720 guess
#      Effettuate 4760 guess
#      Effettuate 4800 guess
#      Effettuate 4840 guess
#      Effettuate 4880 guess
#      Effettuate 4920 guess
#      Effettuate 4960 guess
#      Effettuate 5000 guess
#      Effettuate 5040 guess
#      Effettuate 5080 guess
#      Effettuate 5120 guess
#      Effettuate 5160 guess
#      Effettuate 5200 guess
#      Effettuate 5240 guess
#      Effettuate 5280 guess
#      Effettuate 5320 guess
#      Effettuate 5360 guess
#      Effettuate 5400 guess
#      Effettuate 5440 guess
#      Effettuate 5480 guess
#      Effettuate 5520 guess
#      Effettuate 5560 guess
#      Effettuate 5600 guess
#      Effettuate 5640 guess
#      Effettuate 5680 guess
#      Effettuate 5720 guess
#      Effettuate 5760 guess
#      Effettuate 5800 guess
#      Effettuate 5840 guess
#      Effettuate 5880 guess
#      Effettuate 5920 guess
#      Effettuate 5960 guess
#      Effettuate 6000 guess
#      Effettuate 6040 guess
#      Effettuate 6080 guess
#      Effettuate 6120 guess
#      Effettuate 6160 guess
#      Effettuate 6200 guess
#      Effettuate 6240 guess
#      Effettuate 6280 guess
#      Effettuate 6320 guess
#      Effettuate 6360 guess
#      Effettuate 6400 guess

# %%
# Funzione per confronto visivo
def histConf(data, names):

    # Creo figura e poi riempio ciclando
    fig, ax = plt.subplots(1, 2, figsize=(15, 6))  
    
    for i, name in enumerate(names):
        appo = data[i][:]
        appo = appo/np.sum(appo)
        ax[i].bar(range(len(appo)), appo, color='skyblue', edgecolor='black')
        ax[i].set_xticks(range(len(appo)), [f'Guess {i+1}' for i in range(len(appo))])
        ax[i].set_title(name.split("/")[-1].split(".")[0])

    plt.tight_layout()
    plt.show()

histConf(histo, names)

# %% [markdown]
# ## Confusion matrix

# %%
# Funzione che consente di stampare la matrice di confusione per un certo modello
def confMat(modN, valDir, titM):

    # Importo il modello e le immagini sulle quali effettuare le guess
    model = load_model(modN)  
    datagen = ImageDataGenerator(rescale=1./255)

    valDat = datagen.flow_from_directory(
        valDir,
        target_size=(48, 48),
        color_mode="grayscale",
        batch_size=64,
        class_mode="categorical",
        shuffle=False
    )

    # Predizioni del modello
    pred = model.predict(valDat)

    # Creazione matrice di confusione
    yTr = valDat.classes
    yPr = np.argmax(pred, axis=1)
    cm = confusion_matrix(yTr, yPr, normalize = 'true')
    labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
    title='Confusion matrix: ' + titM

    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45)
    plt.yticks(tick_marks, labels)
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, round(cm[i, j], 2),
                horizontalalignment="center",
                color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('Vera label')
    plt.xlabel('Guess label')
    plt.tight_layout()
    plt.show()

# %%
titM = "first try"
valDir = "../../Dataset/test"  
name = "../../Modelli/firstTry.keras"

confMat(name, valDir, titM)
# Out:
# Found 7178 images belonging to 7 classes.
# /home/filippo/.local/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 15s 127ms/step

# %% [markdown]
# ## Top-k accuracy

# %%
# Funzione per confronto visivo
def histConf(data, name):

    # Creo figura
    fig = plt.subplots(1, 1, figsize=(15, 6))

    # Creazione istogramma
    plt.bar(range(len(appo)), appo, color='skyblue', edgecolor='black')
    plt.xticks(range(len(appo)), [f'k = {i+1}' for i in range(len(appo))])
    plt.title(name)

    plt.tight_layout()
    plt.show()


# Importo true value e guess
yTr = np.load("guess/trueG.npy")
yPr = np.load("guess/firstTry.npy")

# Ciclo sull'indice k (vado da 1 a 6)
ks = [1, 2, 3, 4, 5, 6]
appo = np.zeros(6)
for i in ks:
    appo[i-1] = top_k_accuracy_score(yTr, yPr, k=i, normalize = True)

histConf(appo, "Top-k accuracy: first try model")
# Out:
# [0.54123711 0.72123154 0.83755921 0.91891892 0.97018668 0.99359153]

# %% [markdown]
# ## Capacità di generalizzazione

# %%
datagen = ImageDataGenerator(rescale=1./255)
valDat = datagen.flow_from_directory(
    "../Dataset/test",
    target_size=(48, 48),
    color_mode="grayscale",
    batch_size=64,
    class_mode="categorical",
    shuffle=False
)

labels = valDat.classes
np.save("guess/trueG.npy", labels)
# Out:
# Found 7178 images belonging to 7 classes.
